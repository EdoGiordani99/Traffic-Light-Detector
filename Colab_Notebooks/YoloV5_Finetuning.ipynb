# %% [markdown]
# <a href="https://colab.research.google.com/github/EdoGiordani99/Traffic-Light-Detector/blob/main/YoloV5_Finetuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Object Detection Training Notebook (Yolo V5 fine - tuning)
# <h2>Vision & Perception Project 2021/2022</h2>
# <h3>Student: Edoardo Giordani</h3>
# <h3>E-mail: giordani.2020434@studenti.uniroma1.it</h3>
#
# This notebook was used to fine tuning a Yolo V5 architecture. This approach was the best one thanks to the efficiency of the network.

# %% [markdown]
# ## Install Requirements

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12712, done.
# remote: Counting objects: 100% (137/137), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 12712 (delta 82), reused 125 (delta 74), pack-reused 12575
# Receiving objects: 100% (12712/12712), 12.33 MiB | 7.46 MiB/s, done.
# Resolving deltas: 100% (8739/8739), done.

# %%
# %cd yolov5
# %pip install -q roboflow
# %pip install -qr requirements.txt

# %%
import os
import torch
from roboflow import Roboflow
from google.colab import drive
from IPython.display import Image, clear_output

# %% [markdown]
# ## Mount the drive
# We mount the drive in order to save results and trained model weights on the cloud.

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##Downloading the Dataset
# Here we are downloading our DIY dataset from the Roboflow framework.

# %%
rf = Roboflow(model_format="yolov5", notebook="ultralytics")
os.environ["DATASET_DIRECTORY"] = "/content/datasets"

# %%
rf = Roboflow(api_key="cJ4ImlUPhvj3p4yBOaJj")
project = rf.workspace("traffic-light-detector-bnryi").project("traffic-light-detector-o3g9q")
dataset = project.version(1).download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to /content/datasets/Traffic-Light-Detector-1 in yolov5pytorch:: 100%|██████████| 628/628 [00:01<00:00, 390.66it/s]

# %% [markdown]
# ## Training!
# Finally training: hyper parameters can be changed from the command. Of course, since this is a pretrained model we have to specify the weights file location.

# %%
# !python train.py --img 1024 --batch 8 --epochs 200 --data {dataset.location}/data.yaml --weights yolov5l.pt --cache
# Out:
# train: weights=yolov5l.pt, cfg=, data=/content/datasets/Traffic-Light-Detector-1/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=200, batch_size=8, imgsz=1024, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 1 commit. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.1-303-g2430578 Python-3.7.13 torch-1.11.0+cu102 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %% [markdown]
# ##Tensorboard
# Tensorboard comes in handy to visualize validation metrics and loss plots among all the training session that were done.

# %%
# %reload_ext tensorboard
# %tensorboard --logdir runs

# %% [markdown]
# ##Predict Test Instances
# we use the saved weights to predict the test images.

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 1024 --conf 0.4 --source {dataset.location}/test/images

# %% [markdown]
# ##To Save Predictions on the Drive

# %%
# %cd ..

# copy folder __ to folder __
# !cp -av 'yolov5/runs/detect/exp4' 'drive/MyDrive/V&P/YoloV5/'

# %cd yolov5
